# %% [markdown]
# **Step 3 of MediVerse AI** | Medical Receipt & Prescription Scanner | Online + Offline
#
# # 🏥 MedReceipt-AI: Application Launcher
#
# Welcome to **MedReceipt-AI** (FinanceFlow-AI) — an intelligent, end-to-end Medical Receipt and Prescription Reader.
#
# This notebook is the single, clean entry point to launch and run the Gradio application dashboard. All implementation files have been organized into the `src/` directory to keep your folder workspace clean and uncluttered.
#
# ---
#
# ## 🚀 Setup & Execution Guide
#
# ### 1. Pre-requisites & Dependencies
# Ensure your environment has all dependencies installed. If you haven't done so, you can install them by running the helper cell below.

# %% [markdown]
# ### 2. Launch the Gradio Web App
# Run the cell below to start the Gradio web server. Once running, you can click on the local URL printed (e.g. `http://127.0.0.1:7860`) to open the interactive dashboard in your browser.

# %%
import os
import sys

# 1. Add the 'src' directory to Python's system path to resolve imports dynamically
src_path = os.path.abspath("src")
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# 2. Initialize the database table structure
from database import create_table
create_table()

# 3. Import and launch the Gradio web dashboard
from app_gradio import demo
demo.launch(share=False)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\alpha\OneDrive\Desktop\mediverse\Recipt_reader\FinanceFlow-AI\src\app_gradio.py:141: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['parsed_date'] = pd.to_datetime(df['date'], errors='coerce')
# c:\Users\alpha\OneDrive\Desktop\mediverse\Recipt_reader\FinanceFlow-AI\src\app_gradio.py:141: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['parsed_date'] = pd.to_datetime(df['date'], errors='coerce')
